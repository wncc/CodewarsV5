# %%
#!/usr/bin/env python3
import os
import cv2
import numpy as np

def crop_sprite(image_path, output_path):
    # Load the image with alpha channel (if available)
    image = cv2.imread(image_path, cv2.IMREAD_UNCHANGED)
    if image is None:
        print(f"Failed to load {image_path}")
        return
    
    # Split channels
    if image.shape[2] == 4:
        _, _, _, alpha = cv2.split(image)
    else:
        gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
        _, alpha = cv2.threshold(gray, 1, 255, cv2.THRESH_BINARY)
    
    # Find contours
    contours, _ = cv2.findContours(alpha, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
    if not contours:
        print(f"No foreground found in {image_path}")
        return
    
    # Get bounding box of the largest contour
    x, y, w, h = cv2.boundingRect(contours[0])
    cropped = image[y:y+h, x:x+w]
    
    # Save cropped image
    cv2.imwrite(output_path, cropped)
    print(f"Cropped and saved: {output_path}")

def process_directory(input_dir, output_dir):
    if not os.path.exists(output_dir):
        os.makedirs(output_dir)
    
    for filename in os.listdir(input_dir):
        if filename.lower().endswith(".png"):
            input_path = os.path.join(input_dir, filename)
            output_path = os.path.join(output_dir, filename)
            crop_sprite(input_path, output_path)

def main():
    input_directory = "../data/images/troops/Blue"  # Change this to your input directory
    output_directory = "../data/images/troops/Blue_cropped_sprites"  # Change this to your output directory
    process_directory(input_directory, output_directory)

if __name__ == "__main__":
    main()
# Out:
# Cropped and saved: ../data/images/troops/Blue_cropped_sprites\BlueArcherBack.png
# Cropped and saved: ../data/images/troops/Blue_cropped_sprites\BlueArcherBackAttack.png
# Cropped and saved: ../data/images/troops/Blue_cropped_sprites\BlueArcherFront.png
# Cropped and saved: ../data/images/troops/Blue_cropped_sprites\BlueArcherFrontAttack.png
# Cropped and saved: ../data/images/troops/Blue_cropped_sprites\BlueBarbarianBack.png
# Cropped and saved: ../data/images/troops/Blue_cropped_sprites\BlueBarbarianBackAttack.png
# Cropped and saved: ../data/images/troops/Blue_cropped_sprites\BlueBarbarianFront.png
# Cropped and saved: ../data/images/troops/Blue_cropped_sprites\BlueBarbarianFrontAttack.png
# Cropped and saved: ../data/images/troops/Blue_cropped_sprites\BlueBombTower.png
# Cropped and saved: ../data/images/troops/Blue_cropped_sprites\BlueBombTowerAttack.png
# Cropped and saved: ../data/images/troops/Blue_cropped_sprites\BlueDragonBack.png
# Cropped and saved: ../data/images/troops/Blue_cropped_sprites\BlueDragonBackAttack.png
# Cropped and saved: ../data/images/troops/Blue_cropped_sprites\BlueDragonFront.png
# Cropped and saved: ../data/images/troops/Blue_cropped_sprites\BlueDragonFrontAttack.png
# Cropped and saved: ../data/images/troops/Blue_cropped_sprites\BlueDragonFrontAttackPatch.png
# Cropped and saved: ../data/images/troops/Blue_cropped_sprites\BlueGiantBack.png
# Cropped and saved: ../data/images/troops/Blue_cropped_sprites\BlueGiantBackAttack.png
# Cropped and saved: ../data/images/troops/Blue_cropped_sprites\BlueGiantFront.png
# Cropped and saved: ../data/images/troops/Blue_cropped_sprites\BlueGiantFrontAttack.png
# Cropped and saved: ../data/images/troops/Blue_cropped_sprites\BlueMinionBack.png
# Cropped and saved: ../data/images/troops/Blue_cropped_sprites\BlueMinionBackAttack.png
# Cropped and saved: ../data/images/troops/Blue_cropped_sprites\BlueMinionFront.png
# Cropped and saved: ../data/images/troops/Blue_cropped_sprites\BlueMinionFrontAttack.png
# Cropped and saved: ../data/images/troops/Blue_cropped_sprites\BluePrinceBack.png
# Cropped and saved: ../data/images/troops/Blue_cropped_sprites\BluePrinceBackAttack.png
# Cropped and saved: ../data/images/troops/Blue_cropped_sprites\BluePrinceFront.png
# Cropped and saved: ../data/images/troops/Blue_cropped_sprites\BluePrinceFrontAttack.png
# Cropped and saved: ../data/images/troops/Blue_cropped_sprites\BluePrincessBack.png
# Cropped and saved: ../data/images/troops/Blue_cropped_sprites\BluePrincessBackAttack.png
# Cropped and saved: ../data/images/troops/Blue_cropped_sprites\BluePrincessFront.png
# Cropped and saved: ../data/images/troops/Blue_cropped_sprites\BluePrincessFrontAttack.png
# Cropped and saved: ../data/images/troops/Blue_cropped_sprites\building_firespirit_hut_sprite_11.png

# %%
#!/usr/bin/env python3
import os
import cv2
import numpy as np

def crop_sprite(image_path, output_path):
    # Load the image with alpha channel (if available)
    image = cv2.imread(image_path, cv2.IMREAD_UNCHANGED)
    if image is None:
        print(f"Failed to load {image_path}")
        return
    
    # Split channels
    if image.shape[2] == 4:
        _, _, _, alpha = cv2.split(image)
    else:
        gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
        _, alpha = cv2.threshold(gray, 1, 255, cv2.THRESH_BINARY)
    
    # Find contours
    contours, _ = cv2.findContours(alpha, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
    if not contours:
        print(f"No foreground found in {image_path}")
        return
    
    # Get bounding box of the largest contour
    x, y, w, h = cv2.boundingRect(contours[0])
    cropped = image[y:y+h, x:x+w]
    
    # Save cropped image
    cv2.imwrite(output_path, cropped)
    print(f"Cropped and saved: {output_path}")

def process_directory(input_dir, output_dir):
    if not os.path.exists(output_dir):
        os.makedirs(output_dir)
    
    for filename in os.listdir(input_dir):
        if filename.lower().endswith(".png"):
            input_path = os.path.join(input_dir, filename)
            output_path = os.path.join(output_dir, filename)
            crop_sprite(input_path, output_path)

def main():
    input_directory = "C:/Users/kesha/Desktop/WnCC Stuff-before dec.5/test_left_right_motion_animation"  # Change this to your input directory
    output_directory = "C:/Users/kesha/Desktop/WnCC Stuff-before dec.5/test_left_right_motion_animation/cropped"  # Change this to your output directory
    process_directory(input_directory, output_directory)

if __name__ == "__main__":
    main()
# Out:
# Cropped and saved: C:/Users/kesha/Desktop/WnCC Stuff-before dec.5/test_left_right_motion_animation/cropped\barbarian_attack_e_1.png
# Cropped and saved: C:/Users/kesha/Desktop/WnCC Stuff-before dec.5/test_left_right_motion_animation/cropped\barbarian_attack_e_2.png
# Cropped and saved: C:/Users/kesha/Desktop/WnCC Stuff-before dec.5/test_left_right_motion_animation/cropped\barbarian_attack_e_3.png
# Cropped and saved: C:/Users/kesha/Desktop/WnCC Stuff-before dec.5/test_left_right_motion_animation/cropped\barbarian_attack_e_4.png
# Cropped and saved: C:/Users/kesha/Desktop/WnCC Stuff-before dec.5/test_left_right_motion_animation/cropped\barbarian_attack_e_5.png
# Cropped and saved: C:/Users/kesha/Desktop/WnCC Stuff-before dec.5/test_left_right_motion_animation/cropped\barbarian_attack_e_6.png
# Cropped and saved: C:/Users/kesha/Desktop/WnCC Stuff-before dec.5/test_left_right_motion_animation/cropped\barbarian_attack_ne_1.png
# Cropped and saved: C:/Users/kesha/Desktop/WnCC Stuff-before dec.5/test_left_right_motion_animation/cropped\barbarian_attack_ne_2.png
# Cropped and saved: C:/Users/kesha/Desktop/WnCC Stuff-before dec.5/test_left_right_motion_animation/cropped\barbarian_attack_ne_3.png
# Cropped and saved: C:/Users/kesha/Desktop/WnCC Stuff-before dec.5/test_left_right_motion_animation/cropped\barbarian_attack_ne_4.png
# Cropped and saved: C:/Users/kesha/Desktop/WnCC Stuff-before dec.5/test_left_right_motion_animation/cropped\barbarian_attack_ne_5.png
# Cropped and saved: C:/Users/kesha/Desktop/WnCC Stuff-before dec.5/test_left_right_motion_animation/cropped\barbarian_attack_ne_6.png
# Cropped and saved: C:/Users/kesha/Desktop/WnCC Stuff-before dec.5/test_left_right_motion_animation/cropped\barbarian_attack_nw_1.png
# Cropped and saved: C:/Users/kesha/Desktop/WnCC Stuff-before dec.5/test_left_right_motion_animation/cropped\barbarian_attack_nw_2.png
# Cropped and saved: C:/Users/kesha/Desktop/WnCC Stuff-before dec.5/test_left_right_motion_animation/cropped\barbarian_attack_nw_3.png
# Cropped and saved: C:/Users/kesha/Desktop/WnCC Stuff-before dec.5/test_left_right_motion_animation/cropped\barbarian_attack_nw_4.png
# Cropped and saved: C:/Users/kesha/Desktop/WnCC Stuff-before dec.5/test_left_right_motion_animation/cropped\barbarian_attack_nw_5.png
# Cropped and saved: C:/Users/kesha/Desktop/WnCC Stuff-before dec.5/test_left_right_motion_animation/cropped\barbarian_attack_nw_6.png
# Cropped and saved: C:/Users/kesha/Desktop/WnCC Stuff-before dec.5/test_left_right_motion_animation/cropped\barbarian_attack_n_1.png
# Cropped and saved: C:/Users/kesha/Desktop/WnCC Stuff-before dec.5/test_left_right_motion_animation/cropped\barbarian_attack_n_2.png
# Cropped and saved: C:/Users/kesha/Desktop/WnCC Stuff-before dec.5/test_left_right_motion_animation/cropped\barbarian_attack_n_3.png
# Cropped and saved: C:/Users/kesha/Desktop/WnCC Stuff-before dec.5/test_left_right_motion_animation/cropped\barbarian_attack_n_4.png
# Cropped and saved: C:/Users/kesha/Desktop/WnCC Stuff-before dec.5/test_left_right_motion_animation/cropped\barbarian_attack_n_5.png
# Cropped and saved: C:/Users/kesha/Desktop/WnCC Stuff-before dec.5/test_left_right_motion_animation/cropped\barbarian_attack_n_6.png
# Cropped and saved: C:/Users/kesha/Desktop/WnCC Stuff-before dec.5/test_left_right_motion_animation/cropped\barbarian_attack_se_1.png
# Cropped and saved: C:/Users/kesha/Desktop/WnCC Stuff-before dec.5/test_left_right_motion_animation/cropped\barbarian_attack_se_2.png
# Cropped and saved: C:/Users/kesha/Desktop/WnCC Stuff-before dec.5/test_left_right_motion_animation/cropped\barbarian_attack_se_3.png
# Cropped and saved: C:/Users/kesha/Desktop/WnCC Stuff-before dec.5/test_left_right_motion_animation/cropped\barbarian_attack_se_4.png
# Cropped and saved: C:/Users/kesha/Desktop/WnCC Stuff-before dec.5/test_left_right_motion_animation/cropped\barbarian_attack_se_5.png
# Cropped and saved: C:/Users/kesha/Desktop/WnCC Stuff-before dec.5/test_left_right_motion_animation/cropped\barbarian_attack_se_6.png
# Cropped and saved: C:/Users/kesha/Desktop/WnCC Stuff-before dec.5/test_left_right_motion_animation/cropped\barbarian_attack_sw_1.png
# Cropped and saved: C:/Users/kesha/Desktop/WnCC Stuff-before dec.5/test_left_right_motion_animation/cropped\barbarian_attack_sw_2.png
# Cropped and saved: C:/Users/kesha/Desktop/WnCC Stuff-before dec.5/test_left_right_motion_animation/cropped\barbarian_attack_sw_3.png
# Cropped and saved: C:/Users/kesha/Desktop/WnCC Stuff-before dec.5/test_left_right_motion_animation/cropped\barbarian_attack_sw_4.png
# Cropped and saved: C:/Users/kesha/Desktop/WnCC Stuff-before dec.5/test_left_right_motion_animation/cropped\barbarian_attack_sw_5.png
# Cropped and saved: C:/Users/kesha/Desktop/WnCC Stuff-before dec.5/test_left_right_motion_animation/cropped\barbarian_attack_sw_6.png
# Cropped and saved: C:/Users/kesha/Desktop/WnCC Stuff-before dec.5/test_left_right_motion_animation/cropped\barbarian_attack_s_1.png
# Cropped and saved: C:/Users/kesha/Desktop/WnCC Stuff-before dec.5/test_left_right_motion_animation/cropped\barbarian_attack_s_2.png
# Cropped and saved: C:/Users/kesha/Desktop/WnCC Stuff-before dec.5/test_left_right_motion_animation/cropped\barbarian_attack_s_3.png
# Cropped and saved: C:/Users/kesha/Desktop/WnCC Stuff-before dec.5/test_left_right_motion_animation/cropped\barbarian_attack_s_4.png
# Cropped and saved: C:/Users/kesha/Desktop/WnCC Stuff-before dec.5/test_left_right_motion_animation/cropped\barbarian_attack_s_5.png
# Cropped and saved: C:/Users/kesha/Desktop/WnCC Stuff-before dec.5/test_left_right_motion_animation/cropped\barbarian_attack_s_6.png
# Cropped and saved: C:/Users/kesha/Desktop/WnCC Stuff-before dec.5/test_left_right_motion_animation/cropped\barbarian_attack_w_1.png
# Cropped and saved: C:/Users/kesha/Desktop/WnCC Stuff-before dec.5/test_left_right_motion_animation/cropped\barbarian_attack_w_2.png
# Cropped and saved: C:/Users/kesha/Desktop/WnCC Stuff-before dec.5/test_left_right_motion_animation/cropped\barbarian_attack_w_3.png
# Cropped and saved: C:/Users/kesha/Desktop/WnCC Stuff-before dec.5/test_left_right_motion_animation/cropped\barbarian_attack_w_4.png
# Cropped and saved: C:/Users/kesha/Desktop/WnCC Stuff-before dec.5/test_left_right_motion_animation/cropped\barbarian_attack_w_5.png
# Cropped and saved: C:/Users/kesha/Desktop/WnCC Stuff-before dec.5/test_left_right_motion_animation/cropped\barbarian_attack_w_6.png
# Cropped and saved: C:/Users/kesha/Desktop/WnCC Stuff-before dec.5/test_left_right_motion_animation/cropped\barbarian_run_e_1.png
# Cropped and saved: C:/Users/kesha/Desktop/WnCC Stuff-before dec.5/test_left_right_motion_animation/cropped\barbarian_run_e_2.png
# Cropped and saved: C:/Users/kesha/Desktop/WnCC Stuff-before dec.5/test_left_right_motion_animation/cropped\barbarian_run_e_3.png
# Cropped and saved: C:/Users/kesha/Desktop/WnCC Stuff-before dec.5/test_left_right_motion_animation/cropped\barbarian_run_e_4.png
# Cropped and saved: C:/Users/kesha/Desktop/WnCC Stuff-before dec.5/test_left_right_motion_animation/cropped\barbarian_run_e_5.png
# Cropped and saved: C:/Users/kesha/Desktop/WnCC Stuff-before dec.5/test_left_right_motion_animation/cropped\barbarian_run_e_6.png
# Cropped and saved: C:/Users/kesha/Desktop/WnCC Stuff-before dec.5/test_left_right_motion_animation/cropped\barbarian_run_ne_1.png
# Cropped and saved: C:/Users/kesha/Desktop/WnCC Stuff-before dec.5/test_left_right_motion_animation/cropped\barbarian_run_ne_2.png
# Cropped and saved: C:/Users/kesha/Desktop/WnCC Stuff-before dec.5/test_left_right_motion_animation/cropped\barbarian_run_ne_3.png
# Cropped and saved: C:/Users/kesha/Desktop/WnCC Stuff-before dec.5/test_left_right_motion_animation/cropped\barbarian_run_ne_4.png
# Cropped and saved: C:/Users/kesha/Desktop/WnCC Stuff-before dec.5/test_left_right_motion_animation/cropped\barbarian_run_ne_5.png
# Cropped and saved: C:/Users/kesha/Desktop/WnCC Stuff-before dec.5/test_left_right_motion_animation/cropped\barbarian_run_ne_6.png
# Cropped and saved: C:/Users/kesha/Desktop/WnCC Stuff-before dec.5/test_left_right_motion_animation/cropped\barbarian_run_nw_1.png
# Cropped and saved: C:/Users/kesha/Desktop/WnCC Stuff-before dec.5/test_left_right_motion_animation/cropped\barbarian_run_nw_2.png
# Cropped and saved: C:/Users/kesha/Desktop/WnCC Stuff-before dec.5/test_left_right_motion_animation/cropped\barbarian_run_nw_3.png
# Cropped and saved: C:/Users/kesha/Desktop/WnCC Stuff-before dec.5/test_left_right_motion_animation/cropped\barbarian_run_nw_4.png
# Cropped and saved: C:/Users/kesha/Desktop/WnCC Stuff-before dec.5/test_left_right_motion_animation/cropped\barbarian_run_nw_5.png
# Cropped and saved: C:/Users/kesha/Desktop/WnCC Stuff-before dec.5/test_left_right_motion_animation/cropped\barbarian_run_nw_6.png
# Cropped and saved: C:/Users/kesha/Desktop/WnCC Stuff-before dec.5/test_left_right_motion_animation/cropped\barbarian_run_n_1.png
# Cropped and saved: C:/Users/kesha/Desktop/WnCC Stuff-before dec.5/test_left_right_motion_animation/cropped\barbarian_run_n_2.png
# Cropped and saved: C:/Users/kesha/Desktop/WnCC Stuff-before dec.5/test_left_right_motion_animation/cropped\barbarian_run_n_3.png
# Cropped and saved: C:/Users/kesha/Desktop/WnCC Stuff-before dec.5/test_left_right_motion_animation/cropped\barbarian_run_n_4.png
# Cropped and saved: C:/Users/kesha/Desktop/WnCC Stuff-before dec.5/test_left_right_motion_animation/cropped\barbarian_run_n_5.png
# Cropped and saved: C:/Users/kesha/Desktop/WnCC Stuff-before dec.5/test_left_right_motion_animation/cropped\barbarian_run_n_6.png
# Cropped and saved: C:/Users/kesha/Desktop/WnCC Stuff-before dec.5/test_left_right_motion_animation/cropped\barbarian_run_se_1.png
# Cropped and saved: C:/Users/kesha/Desktop/WnCC Stuff-before dec.5/test_left_right_motion_animation/cropped\barbarian_run_se_2.png
# Cropped and saved: C:/Users/kesha/Desktop/WnCC Stuff-before dec.5/test_left_right_motion_animation/cropped\barbarian_run_se_3.png
# Cropped and saved: C:/Users/kesha/Desktop/WnCC Stuff-before dec.5/test_left_right_motion_animation/cropped\barbarian_run_se_4.png
# Cropped and saved: C:/Users/kesha/Desktop/WnCC Stuff-before dec.5/test_left_right_motion_animation/cropped\barbarian_run_se_5.png
# Cropped and saved: C:/Users/kesha/Desktop/WnCC Stuff-before dec.5/test_left_right_motion_animation/cropped\barbarian_run_se_6.png
# Cropped and saved: C:/Users/kesha/Desktop/WnCC Stuff-before dec.5/test_left_right_motion_animation/cropped\barbarian_run_sw_1.png
# Cropped and saved: C:/Users/kesha/Desktop/WnCC Stuff-before dec.5/test_left_right_motion_animation/cropped\barbarian_run_sw_2.png
# Cropped and saved: C:/Users/kesha/Desktop/WnCC Stuff-before dec.5/test_left_right_motion_animation/cropped\barbarian_run_sw_3.png
# Cropped and saved: C:/Users/kesha/Desktop/WnCC Stuff-before dec.5/test_left_right_motion_animation/cropped\barbarian_run_sw_4.png
# Cropped and saved: C:/Users/kesha/Desktop/WnCC Stuff-before dec.5/test_left_right_motion_animation/cropped\barbarian_run_sw_5.png
# Cropped and saved: C:/Users/kesha/Desktop/WnCC Stuff-before dec.5/test_left_right_motion_animation/cropped\barbarian_run_sw_6.png
# Cropped and saved: C:/Users/kesha/Desktop/WnCC Stuff-before dec.5/test_left_right_motion_animation/cropped\barbarian_run_s_1.png
# Cropped and saved: C:/Users/kesha/Desktop/WnCC Stuff-before dec.5/test_left_right_motion_animation/cropped\barbarian_run_s_2.png
# Cropped and saved: C:/Users/kesha/Desktop/WnCC Stuff-before dec.5/test_left_right_motion_animation/cropped\barbarian_run_s_3.png
# Cropped and saved: C:/Users/kesha/Desktop/WnCC Stuff-before dec.5/test_left_right_motion_animation/cropped\barbarian_run_s_4.png
# Cropped and saved: C:/Users/kesha/Desktop/WnCC Stuff-before dec.5/test_left_right_motion_animation/cropped\barbarian_run_s_5.png
# Cropped and saved: C:/Users/kesha/Desktop/WnCC Stuff-before dec.5/test_left_right_motion_animation/cropped\barbarian_run_s_6.png
# Cropped and saved: C:/Users/kesha/Desktop/WnCC Stuff-before dec.5/test_left_right_motion_animation/cropped\barbarian_run_w_1.png
# Cropped and saved: C:/Users/kesha/Desktop/WnCC Stuff-before dec.5/test_left_right_motion_animation/cropped\barbarian_run_w_2.png
# Cropped and saved: C:/Users/kesha/Desktop/WnCC Stuff-before dec.5/test_left_right_motion_animation/cropped\barbarian_run_w_3.png
# Cropped and saved: C:/Users/kesha/Desktop/WnCC Stuff-before dec.5/test_left_right_motion_animation/cropped\barbarian_run_w_4.png
# Cropped and saved: C:/Users/kesha/Desktop/WnCC Stuff-before dec.5/test_left_right_motion_animation/cropped\barbarian_run_w_5.png
# Cropped and saved: C:/Users/kesha/Desktop/WnCC Stuff-before dec.5/test_left_right_motion_animation/cropped\barbarian_run_w_6.png

# %%
# !pip install opencv-python
# Out:
# Collecting opencv-python
#   Using cached opencv_python-4.11.0.86-cp37-abi3-win_amd64.whl.metadata (20 kB)
# Requirement already satisfied: numpy>=1.21.2 in c:\users\kesha\anaconda3\envs\test\lib\site-packages (from opencv-python) (2.2.3)
# Using cached opencv_python-4.11.0.86-cp37-abi3-win_amd64.whl (39.5 MB)
# Installing collected packages: opencv-python
# Successfully installed opencv-python-4.11.0.86
